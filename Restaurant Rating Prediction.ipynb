# %%
import pandas as pd
# %pip install matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.14/site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in ./.venv/lib/python3.14/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in ./.venv/lib/python3.14/site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in ./.venv/lib/python3.14/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('Dataset .csv.xls')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   str
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   str
#  4   Address               9551 non-null   str
#  5   Locality              9551 non-null   str
#  6   Locality Verbose      9551 non-null   str
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   str
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   str
#  12  Has Table booking     9551 non-null   str
#  13  Has Online delivery   9551 non-null   str
#  14  Is delivering now     9551 non-null   str
#  15  Switch to order menu  9551 non-null   str
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   str
#  19  Rating text           9551 non-null   str
#  20  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), str(13)
# memory usage: 3.1 MB

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='str')

# %%
#Group by city and calculate average cost
df.groupby("City")["Average Cost for two"].mean().sort_values(ascending=False).head().plot(kind="bar")
plt.title("Average cost for two per city, top 5")
plt.xlabel("City")
plt.ylabel("Amount")
plt.grid()
plt.show()

# %%
#Cuisines total number of votes
data = df.groupby("Cuisines")["Votes"].sum().reset_index()

# %%
data[data["Votes"] != 0]
# Out:
#                                        Cuisines  Votes
# 0                                       Afghani     39
# 1                     Afghani, Mughlai, Chinese      2
# 3     Afghani, North Indian, Pakistani, Arabian      3
# 4                                       African    373
# 5                           African, Portuguese    265
# ...                                         ...    ...
# 1820                       Western, Asian, Cafe    259
# 1821                 Western, Fusion, Fast Food     32
# 1822                              World Cuisine     95
# 1823            World Cuisine, Mexican, Italian    115
# 1824            World Cuisine, Patisserie, Cafe   1034
#
# [1777 rows x 2 columns]

# %%
sns.pairplot(df[["Average Cost for two", "Aggregate rating","Votes"]])

# %%
df["Has Online delivery"].value_counts().plot(kind="pie")
plt.title("Has Online delivery?")
plt.ylabel("")
plt.legend()
plt.show()

# %%
df = df[df["Rating text"] != "Not rated"]

# %%
df["Rating text"].value_counts().plot(kind="pie")
plt.title("Rating Averages")
plt.ylabel("")
plt.legend()
plt.show()

# %%
X = df[['Average Cost for two', 'Has Table booking', 'Has Online delivery', 'Price range']]

# %%
# Above 2 below 2.5  Poor
# Above 2.5 below 3.4  Average
# Above 3.5 below 4.0  Good
# Above 4 below 4.5  Very good
# Above 4.5  Excellent

# %%
y = df[["Aggregate rating"]]

# %%
X["Price range"].value_counts()
# Out:
# Price range
# 1    2744
# 2    2711
# 3    1373
# 4     575
# Name: count, dtype: int64

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
X["Has Table booking"] = labelencoder.fit_transform(X["Has Table booking"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                     1100                  1                  No            3
# 1                     1200                  1                  No            3
# 2                     4000                  1                  No            4
# 3                     1500                  0                  No            4
# 4                     1500                  1                  No            4
# ...                    ...                ...                 ...          ...
# 9546                    80                  0                  No            3
# 9547                   105                  0                  No            3
# 9548                   170                  0                  No            4
# 9549                   120                  0                  No            4
# 9550                    55                  0                  No            2
#
# [7403 rows x 4 columns]

# %%
X["Has Online delivery"] = labelencoder.fit_transform(X["Has Online delivery"])

# %%
labelencoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Has table booking 0 is no 1 is yes
# Has Online delivery 0 is no 1 is yes

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]],
#       shape=(7403, 4))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.values.ravel(), test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
def modelresults(predictions):
  print("Mean absolute error on model is {}".format(mean_absolute_error(y_test, predictions)))
  print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictionsfromlr = lr.predict(X_test)

# %%
modelresults(predictionsfromlr)
# Out:
# Mean absolute error on model is 0.4093638791700241
# Root mean squared error on model is 0.5162330389766026

# %%
predictionsfromlr
# Out:
# array([4.02060223, 3.1554036 , 3.23060644, ..., 3.23020327, 3.94385784,
#        4.01906068], shape=(1481,))

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
svrmodel = SVR()

# %%
param_gridsvr = {"C" : [0.1, 0.5], "kernel" : ["linear", "poly"], "degree" : [2]}

# %%
gridsvr = GridSearchCV(svrmodel, param_gridsvr)
gridsvr.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 0.5], 'degree': [2],
#                          'kernel': ['linear', 'poly']})

# %%
predsgridsvr = gridsvr.predict(X_test)

# %%
modelresults(predsgridsvr)
# Out:
# Mean absolute error on model is 0.40425842831105613
# Root mean squared error on model is 0.5164928969901961

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {
    "max_depth" : [10,30],
    "min_samples_leaf" : [1,2],
    "min_samples_split" : [2,5]
}

# %%
treemodel = DecisionTreeRegressor()

# %%
grid_tree = GridSearchCV(estimator= treemodel, param_grid = param_grid)

# %%
grid_tree.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %%
treepredictions = grid_tree.predict(X_test)

# %%
modelresults(treepredictions)
# Out:
# Mean absolute error on model is 0.3678781886509398
# Root mean squared error on model is 0.4679438020249536

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfrmodel = RandomForestRegressor()

# %%
param_gridrfr = {"max_depth" : [5,15], "n_estimators" : [2,5,10]}

# %%
gridrfr = GridSearchCV(rfrmodel, param_gridrfr)

# %%
gridrfr.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
randomforestpredictions = gridrfr.predict(X_test)

# %%
modelresults(randomforestpredictions)
# Out:
# Mean absolute error on model is 0.37131448834362873
# Root mean squared error on model is 0.47135768071729917

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 10}

# %%
grid_tree.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors" : [9,11,14,15,16]}
knn_grid_search = GridSearchCV(knn, knn_param_grid)
knn_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [9, 11, 14, 15, 16]})

# %%
knnpreds = knn_grid_search.predict(X_test)

# %%
modelresults(knnpreds)
# Out:
# Mean absolute error on model is 0.3717800472653612
# Root mean squared error on model is 0.47307592000522636

# %%
knn_grid_search.best_params_
# Out:
# {'n_neighbors': 16}

# %%
import streamlit as st
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada_param_grid = {"n_estimators" : [50,100,200],
                  "learning_rate" : [0.1,0.5,1]}
ada_grid_search = GridSearchCV(ada, ada_param_grid)

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in ./.venv/lib/python3.14/site-packages (1.61.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: numpy<3,>=1.23 in ./.venv/lib/python3.14/site-packages (from streamlit) (2.5.2)
# Requirement already satisfied: packaging>=20 in ./.venv/lib/python3.14/site-packages (from streamlit) (26.3)
# Requirement already satisfied: pandas<4,>=1.4.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (3.0.5)
# Requirement already satisfied: pillow<13,>=7.1.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.venv/lib/python3.14/site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=5.26.1 in ./.venv/lib/python3.14/site-packages (from streamlit) (7.35.1)
# Requirement already satisfied: pyarrow<25,>=7.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in ./.venv/lib/python3.14/site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.venv/lib/python3.14/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette<1.4.0,>=0.46.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (0.52.1)
# Requirement already satisfied: httptools<1,>=0.6.3 in ./.venv/lib/python3.14/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (4.14.2)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in ./.venv/lib/python3.14/site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in ./.venv/lib/python3.14/site-packages (from streamlit) (16.1.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in ./.venv/lib/python3.14/site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.14/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.14/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in ./.venv/lib/python3.14/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2.24.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.14/site-packages (from anyio<5,>=4.0.0->streamlit) (3.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.14/site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit) (2026.7.22)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.14/site-packages (from uvicorn<1,>=0.30.0->streamlit) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.14/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
ada_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.1, 0.5, 1],
#                          'n_estimators': [50, 100, 200]})

# %%
adapreds = ada_grid_search.predict(X_test)

# %%
modelresults(adapreds)
# Out:
# Mean absolute error on model is 0.3835610049748928
# Root mean squared error on model is 0.4842373627551054

# %%
gridrfr
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
import joblib
joblib.dump(gridrfr,"mlmodel.pkl")
# Out:
# ['mlmodel.pkl']

# %%
scaler
# Out:
# StandardScaler()

# %%
joblib.dump(scaler,"Scaler.pkl")
# Out:
# ['Scaler.pkl']
